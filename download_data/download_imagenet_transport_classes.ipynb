# %%
import os

# %%
os.mkdir('../images/transport')
os.mkdir('../images/not_transport')

# %%
transport_synid = open('../dataset/transport_synid_textfile.txt', 'r')
transport_synid = transport_synid.read().split('\n')
transport_synid.pop()
del transport_synid[:13]

# %%
not_transport_synid = open('../dataset/not_transport_synid_textfile.txt', 'r')
not_transport_synid = not_transport_synid.read().split('\n')
not_transport_synid.pop()
# Out:
# ''

# %%
print('Length of transport_synid:', len(transport_synid))
print('Length of not_transport_synid:', len(not_transport_synid))
# Out:
# Length of transport_synid: 580
# Length of not_transport_synid: 500

# %%
transport_synid = ' '.join(transport_synid)
not_transport_synid = ' '.join(not_transport_synid)

# %%
print('dtype of transport_synid', type(transport_synid))
print('dtype of not_transport_synid', type(not_transport_synid))
# Out:
# dtype of transport_synid <class 'str'>
# dtype of not_transport_synid <class 'str'>

# %% [markdown]
# ### Transport Dataset

# %%
# !python ImageNet-Datasets-Downloader/downloader.py \
-data_root ../images/transport/ \
-use_class_list True \
-class_list $transport_synid \
-images_per_class 30
# Out:
# Picked the following clases:
# Count: 580
# ...

# %% [markdown]
# ### Not Transport Dataset

# %%
# !python ImageNet-Datasets-Downloader/downloader.py \
-data_root ../images/not_transport/ \
-use_class_list True \
-class_list $not_transport_synid \
-images_per_class 30
# Out:
# Picked the following clases:
# Count: 500
# ...
